# %%
from torchinfo import summary
from ultralytics import YOLO

# %%
model = YOLO('l-vehicle-accident.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (1,728)
# │    │    └─BatchNorm2d: 3-2                                 (128)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (73,728)
# │    │    └─BatchNorm2d: 3-5                                 (256)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (16,640)
# │    │    └─Conv: 3-8                                        (66,048)
# ...

# %%
model = YOLO('l-vehicle.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (1,728)
# │    │    └─BatchNorm2d: 3-2                                 (128)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (73,728)
# │    │    └─BatchNorm2d: 3-5                                 (256)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (16,640)
# │    │    └─Conv: 3-8                                        (66,048)
# ...

# %%
model = YOLO('l-accident.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (1,728)
# │    │    └─BatchNorm2d: 3-2                                 (128)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (73,728)
# │    │    └─BatchNorm2d: 3-5                                 (256)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (16,640)
# │    │    └─Conv: 3-8                                        (66,048)
# ...

# %%
model = YOLO('n-vehicle-accident.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (432)
# │    │    └─BatchNorm2d: 3-2                                 (32)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (4,608)
# │    │    └─BatchNorm2d: 3-5                                 (64)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (1,088)
# │    │    └─Conv: 3-8                                        (3,200)
# ...

# %%
model = YOLO('n-removebg-vehicle-accident.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (432)
# │    │    └─BatchNorm2d: 3-2                                 (32)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (4,608)
# │    │    └─BatchNorm2d: 3-5                                 (64)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (1,088)
# │    │    └─Conv: 3-8                                        (3,200)
# ...

# %%
model = YOLO('n-vehicle.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (432)
# │    │    └─BatchNorm2d: 3-2                                 (32)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (4,608)
# │    │    └─BatchNorm2d: 3-5                                 (64)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (1,088)
# │    │    └─Conv: 3-8                                        (3,200)
# ...

# %%
model = YOLO('n-accident.pt')

summary(model.model, verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                                       Param #
# ...
# DetectionModel                                               --
# ├─Sequential: 1-1                                            --
# │    └─Conv: 2-1                                             --
# │    │    └─Conv2d: 3-1                                      (432)
# │    │    └─BatchNorm2d: 3-2                                 (32)
# │    │    └─SiLU: 3-3                                        --
# │    └─Conv: 2-2                                             --
# │    │    └─Conv2d: 3-4                                      (4,608)
# │    │    └─BatchNorm2d: 3-5                                 (64)
# │    │    └─SiLU: 3-6                                        --
# │    └─C3k2: 2-3                                             --
# │    │    └─Conv: 3-7                                        (1,088)
# │    │    └─Conv: 3-8                                        (3,200)
# ...
